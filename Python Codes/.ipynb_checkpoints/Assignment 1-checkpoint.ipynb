# %%
## Import Libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load the data
data_ml = pd.read_table("/Users/ajimuddin/Desktop/NJIT Teaching/FIN-611-Online/Data/data_ml.csv", sep = ',', parse_dates=['date'] )

# %%
#print the name of all the columns
data_ml.columns
# Out:
# Index(['stock_id', 'date', 'Advt_12M_Usd', 'Advt_3M_Usd', 'Advt_6M_Usd',
#        'Asset_Turnover', 'Bb_Yld', 'Bv', 'Capex_Ps_Cf', 'Capex_Sales',
#        'Cash_Div_Cf', 'Cash_Per_Share', 'Cf_Sales', 'Debtequity', 'Div_Yld',
#        'Dps', 'Ebit_Bv', 'Ebit_Noa', 'Ebit_Oa', 'Ebit_Ta', 'Ebitda_Margin',
#        'Eps', 'Eps_Basic', 'Eps_Basic_Gr', 'Eps_Contin_Oper', 'Eps_Dil', 'Ev',
#        'Ev_Ebitda', 'Fa_Ci', 'Fcf', 'Fcf_Bv', 'Fcf_Ce', 'Fcf_Margin',
#        'Fcf_Noa', 'Fcf_Oa', 'Fcf_Ta', 'Fcf_Tbv', 'Fcf_Toa', 'Fcf_Yld',
#        'Free_Ps_Cf', 'Int_Rev', 'Interest_Expense', 'Mkt_Cap_12M_Usd',
#        'Mkt_Cap_3M_Usd', 'Mkt_Cap_6M_Usd', 'Mom_11M_Usd', 'Mom_5M_Usd',
#        'Mom_Sharp_11M_Usd', 'Mom_Sharp_5M_Usd', 'Nd_Ebitda', 'Net_Debt',
#        'Net_Debt_Cf', 'Net_Margin', 'Netdebtyield', 'Ni', 'Ni_Avail_Margin',
#        'Ni_Oa', 'Ni_Toa', 'Noa', 'Oa', 'Ocf', 'Ocf_Bv', 'Ocf_Ce', 'Ocf_Margin',
#        'Ocf_Noa', 'Ocf_Oa', 'Ocf_Ta', 'Ocf_Tbv', 'Ocf_Toa', 'Op_Margin',
# ...

# %%
#print the top 5 row of the data
data_ml.head()
# Out:
#    stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 0        13 2006-12-31          0.25         0.33         0.27
# 1        13 2007-01-31          0.25         0.32         0.28
# 2        13 2007-02-28          0.26         0.30         0.30
# 3        17 2015-03-31          0.73         0.64         0.70
# 4        17 2015-04-30          0.72         0.62         0.66
#
#    Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  Total_Capital  \
# 0            0.22    0.33  0.01         0.13         0.84  ...           0.02
# 1            0.22    0.40  0.01         0.13         0.84  ...           0.02
# 2            0.22    0.15  0.01         0.13         0.84  ...           0.02
# 3            0.40    0.47  0.01         0.70         0.74  ...           0.40
# 4            0.40    0.46  0.01         0.70         0.74  ...           0.40
#
#    Total_Debt  Total_Debt_Capital  Total_Liabilities_Total_Assets  Vol1Y_Usd  \
# ...

# %%
#print the descriptive statistics of  ''Asset_Turnover', 'Cash_Per_Share', 'Interest_Expense', 'Eps', 'Net_Margin', 'Mkt_Cap_12M_Usd', 'Roa', 'Roe', 'Ta','Total_Debt','Vol1Y_Usd', 'R1M_Usd',
data_ml[['Asset_Turnover', 'Cash_Per_Share', 'Interest_Expense', 'Eps', 'Net_Margin', 'Mkt_Cap_12M_Usd', 'Roa', 'Roe', 'Ta', 'Total_Debt', 'Vol1Y_Usd', 'R1M_Usd']]
# Out:
#         Asset_Turnover  Cash_Per_Share  Interest_Expense   Eps  Net_Margin  \
# 0                 0.22            0.16              0.24  0.03        0.01
# 1                 0.22            0.16              0.24  0.03        0.01
# 2                 0.22            0.16              0.24  0.03        0.01
# 3                 0.40            0.18              0.80  0.01        0.01
# 4                 0.40            0.18              0.80  0.01        0.01
# ...                ...             ...               ...   ...         ...
# 283375            0.19            0.19              1.00  0.13        0.12
# 283376            0.19            0.18              1.00  0.13        0.16
# 283377            0.19            0.18              1.00  0.13        0.16
# 283378            0.18            0.22              1.00  0.13        0.22
# 283379            0.60            0.18              0.50  0.08        0.08
#
# ...

# %%
# Graphically show the raltionship between  'Ta', and 'R1M_Usd'; and 'Total_Capital' and 'Total_Debt'. Use proper axis and figure title. 
# Scatterplot. 
plt.scatter(data_ml['Total_Capital'],data_ml['Total_Debt'])
plt.show()

# %%
# Sort the data by dates 
# Divide the data into two parts and named them train_data and test data. 
# Train the data should consist all the dates before 01/01/2015
# The test data should consist all the dates from 01/01/2015

# %%
data_ml.sort_values(by ='date', inplace =True)

# %%
train_data = data_ml[data_ml['date']<'01/01/2015']

# %%
train_data
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 141020       191 1998-11-30          0.23         0.15         0.19
# 177501       124 1998-11-30          0.78         0.64         0.71
# 282470       950 1998-11-30          1.00         1.00         1.00
# 148895      1171 1998-11-30          0.86         0.87         0.85
# 67282        514 1998-11-30          0.11         0.09         0.09
# ...          ...        ...           ...          ...          ...
# 86917        290 2014-12-31          0.14         0.15         0.15
# 202365      1095 2014-12-31          0.49         0.47         0.48
# 183982       464 2014-12-31          0.56         0.58         0.58
# 86146       1184 2014-12-31          0.11         0.09         0.10
# 136102       561 2014-12-31          0.01         0.01         0.01
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 141020            0.50    0.08  0.50         0.49         0.12  ...
# ...

# %%
test_data = data_ml[data_ml['date']>='01/01/2015']

# %%
test_data
# Out:
#         stock_id       date  Advt_12M_Usd  Advt_3M_Usd  Advt_6M_Usd  \
# 13766        990 2015-01-31          0.33         0.38         0.31
# 282423       943 2015-01-31          1.00         1.00         1.00
# 274760      1124 2015-01-31          0.93         0.93         0.93
# 20325        178 2015-01-31          0.02         0.01         0.01
# 264125      1194 2015-01-31          0.85         0.80         0.82
# ...          ...        ...           ...          ...          ...
# 22625       1117 2019-03-31          0.05         0.04         0.05
# 92897        378 2019-03-31          0.33         0.38         0.36
# 154238      1040 2019-03-31          0.22         0.24         0.24
# 78994        579 2019-03-31          0.14         0.22         0.18
# 5046         837 2019-03-31          0.05         0.04         0.04
#
#         Asset_Turnover  Bb_Yld    Bv  Capex_Ps_Cf  Capex_Sales  ...  \
# 13766             0.01    0.09  0.05         0.01         0.01  ...
# ...

# %%
#print the descriptive statistics of train_data and test_data for the variables in Q.2
